# %% [markdown]
# ## User guide
# The software consists of three modules listed below, which allow processing of FCS data. Follow the link to learn more about the modules.
# - [__*Import PTU*__](Import_PTU.ipynb#Import-PTU)
# - [__*Time-binned correlation*__](Time-binned.ipynb#time_binned)
# - [__*FCS fitting*__](FCS_fitting.ipynb#fcs_fit)
#
# By default, the FcsIT starts up in the [__*FCS fitting*__](#fcs_fit) mode. The other modules can be selected from the Methods menu; see image below.
# ```{image} ./img/modules.png
#     :alt: Modules
#     :width: 80%
#     :align: center

# %% [markdown]
#  In the _About_ menu there are links to:
#   - _Help_ opens this manualin a webbrowser
#   - _License_ - opens the pop-up window with the text of the License
#   - inforamtion about the version of the software. I new version will be availabble in the main branch on repository site, the link will change the collor and after clicking will update the software. !!!IMPORTANT!!! Version veriffication as well as dowloading the latest version requires internet connection.

# %% [markdown]
# ```{image} ./img/About.png
#     :alt: Modules
#     :width: 80%
#     :align: center
