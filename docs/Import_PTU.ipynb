# %% [markdown]
# ## Import PTU
# The __*Import PTU*__ method extracts TTTR data from PicoQuant _.ptu_ and _.pt3_ files through the `phconvert` reader. T2 files without nanotimes are retained as continuous-wave data; time gating is available only when TCSPC nanotimes are present. This module allows the user to filter TCSPC data using time gating and/or statistical filtering based on fluorescence-lifetime decay. It is also possible to exclude unwanted parts of the time trace and correlate the fluorescence fluctuation signal. Below is a detailed workflow for using the __*Import PTU*__ module.
#
# ##### **Import PTU files**
# The software recognises all _.ptu_ and _.pt3_ files in the selected folder. Keep files from one experiment in a single folder. Select _Open PTU/PT3 files directory_ from the _File_ menu to open it.

# %% [markdown]
#
# ```{image} ./img/import_ptu/open_ptu_folder.png
#     :alt: open ptu folder
#     :width: 80%
#     :align: center

# %% [markdown]
# In the pop-up window, select the folder where you store your data. The list of files in the chosen directory will appear in the list box at the top-left of the window.

# %% [markdown]
#
# ```{image} ./img/import_ptu/list_of_files.png
#     :alt: list of files
#     :width: 100%
#     :align: center

# %% [markdown]
# ##### **The time-trace plots and the correlation control panel**
# ###### *The time-trace plots*
# The fluorescence time-trace signal is displayed in the top centre part of the window.

# %% [markdown]
# ```{image} ./img/import_ptu/TT_plots.png
#     :alt: TT plots
#     :width: 100%
#     :align: center

# %% [markdown]
# For data with a single fluorescence channel, only one plot is displayed. For two channels, the two separate time-traces are plotted. In the control panel on the left-hand side of the window, below the list of files, the correlation parameters controllers are located.

# %% [markdown]
# ###### *The correlation control panel*
# ```{image} ./img/import_ptu/corr_contols.png
#     :alt: corr contols
#     :width: 1000%
#     :align: center

# %% [markdown]
#
# ```{image} ./img/import_ptu/corr_contols_zoom.png
#     :alt: corr contols
#     :width: 80%
#     :align: center

# %% [markdown]
#
# - The **time bin** field changes the time resolution in which the time-trace signal is being displayed. Its value does not influence the correlation data. After clicking, the user can provide the time resolution. Note the resolution should be given in the exponential notation in seconds, where 1e-3s  = 1ms.
# - The **Npoints** field defines the output number of points in the correlation curve.
# - The **Nchunks** field defines the number of chunks to which the whole time-trace signal is divided. The chunks are used to determine the mean and standard error of the mean for each lag-time point along the correlation curve; for details, see the preprint {cite}`kalwarczyk2026`. By default, the time-trace is divided into thirty evenly distributed chunks.
# - The **Custom chunks** checkbox activates/deactivates user-defined chunks. When activated, the draglines and green fields appear on the time-trace plots. The user can unselect part of the signal that won't be included in the analysis. The length of chunks influences the calculated maximum lag-time of the correlation curve.
# - The **Tau (min)** field defines the minimal lag-time of the correlation curve.
# - The **Tau (max)** field defines the maximal lag-time of the correlation curve.

# %% [markdown]
# ##### **The TCSPC plots, data filtering and correlation plots**
# Below the time-trace plots, there is a window with the TCSPC histograms and Correlation tabs, each containing one or two plots, depending on the number of channels in a given _.ptu_ file.
# ###### *The TCSPC plots and data filtering*
# By default, the TCSPC tab is active at startup.

# %% [markdown]
#  ```{image} ./img/import_ptu/TCSPC_tab.png
#     :alt: TCSPC tab
#     :width: 100%
#     :align: center

# %% [markdown]
# First, the imported _.ptu_ file needs to be filtered. The filtration method can be selected by checking/unchecking the checkboxes _Use time-gating_ or _TCSPC background filtering_.

# %% [markdown]
#  ```{image} ./img/import_ptu/TCSPC_filtering_opps.png
#     :alt: TCSPC filtering opps
#     :width: 100%
#     :align: center

# %% [markdown]
# - *Use time-gating* enables the selection of the part of the TCSPC histogram that will be included in the analysis. The active part of the signal is marked in green. The photons that fall into the inactive range of the histograms (grey parts of the plots marked in grey) will not be included in the analysis. The software recognises whether the measurement was performed in the PIE mode and automatically adjusts the predefined ranges to those dedicated to specific PIE lines. The vertical drag lines on the TCSPC histograms determine the user-defined time gating.
# - _TCSPC background filtering_ uses the algorithms and methods described in the literature: {cite}`enderlein2005`, {cite}`kapusta2007`. The level of background taken into account during filtering can be selected by moving the horizontal drag line on the TCSPC histogram.

# %% [markdown]
#  ```{image} ./img/import_ptu/TCSPC_hitsograms.png
#     :alt: TCSPC filtering opps
#     :width: 100%
#     :align: center

# %% [markdown]
# - Selecting none of the checkboxes will result in an unfiltered signal.
#   For typical FCS measurements, both checkboxes must be selected.
#
# Press the _Calculate filter_ button to calculate the filtering masks for a single file only.
# Press _Calclulate filter for all_ button to calculate the filtering masks for all files from the list.

# %% [markdown]
#  ```{image} ./img/import_ptu/Calc_filter.png
#     :alt: Calc filter
#     :width: 100%
#     :align: center

# %% [markdown]
# ###### *The Correlation plots*
# Once the filters are calculated, switch to the Correlation tab.

# %% [markdown]
#  ```{image} ./img/import_ptu/Corr_tab.png
#     :alt: Corr tab
#     :width: 100%
#     :align: center

# %% [markdown]
# Press the _Calculate correlation_ to calculate correlation curves for a single file.
# Press the _Calculate correlation for all_ button to calculate correlation curves for all listed files.

# %% [markdown]
#  ```{image} ./img/import_ptu/Calc_corr.png
#     :alt: Calc corr
#     :width: 100%
#     :align: center

# %% [markdown]
# ###### *Export correlation curves*
# The calculated correlation curves can be exported either for a single file or all files at once. The FCS curves are exported in one of the following formats:
#  - _.dat_ is a raw ASCII file containing three columns: the correlation time axis, correlation values, and the corresponding standard error

# %% [markdown]
#  ```{image} ./img/import_ptu/export_dat.png
#     :alt: export dat
#     :width: 100%
#     :align: center

# %% [markdown]
#  - _.corr_ format is a binary format consisting of the same data as in the case of the ASCII files. Additionally, the _.corr_ files include the average count rate (averaged across all chunks) and the correlation curves calculated for each chunk. The mean count rate is particularly useful for calculating the molecular brightness of the probe when fitting with the [__*FCS fitting*__](FCS_fitting.ipynb#FCS-fitting)  module.

# %% [markdown]
#  ```{image} ./img/import_ptu/export_corr.png
#     :alt: export corr
#     :width: 100%
#     :align: center

# %% [markdown]
# The exported corralation curves will be stored in four separate folders automatically created in the user-defined folder. The folders are named as:
# - AutoCorr_ch1 - Autocorrelation data corresponding to channel 1,
# - AutoCorr_ch2 - Autocorrelation data corresponding to channel 2 (if available),
# - CrossCorr_ch1 - Crosscorrelation data between channels 1 to 2 (if available),
# - CrossCorr_ch2  - Crosscorrelation data between channels 2 to 1 (if available).
